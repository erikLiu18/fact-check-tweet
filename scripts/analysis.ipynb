# %% [markdown]
# # Covid Fact Check Claims Analysis
# The notebook analyzes the claims data for the Covid topic. The dataset is downloaded from the Google Fact Check Tools API using "covid" as the search query. The scraping was performed on 2025-02-18.

# %%
import pandas as pd
import json

def load_claims_from_file(filename='../data/covid.json'):
    with open(filename, 'r') as json_file:
        return json.load(json_file)

def convert_claims_to_dataframe(claims):
    # Normalize the claimReview field to flatten the structure
    claims_data = []
    for claim in claims:
        for review in claim.get('claimReview', []):
            claims_data.append({
                'text': claim.get('text'),
                'claimant': claim.get('claimant'),
                'claimDate': pd.to_datetime(claim.get('claimDate')),
                'publisher': review.get('publisher', {}).get('name'),
                'reviewUrl': review.get('url'),
                'reviewTitle': review.get('title'), 
                'reviewDate': pd.to_datetime(review.get('reviewDate')),
                'textualRating': review.get('textualRating')
            })
    return pd.DataFrame(claims_data)

# %%
claims = load_claims_from_file()
df = convert_claims_to_dataframe(claims)

display(df.head(10))
# Out:
#                                                 text  \
# 0                           Covid-19 does not exist.
# 1  2021 video of corpses floating in Ganga during...
# 2  Podcaster Ranveer Allahbadia’s 3-year-old vide...
# 3  Pfizer releases new list of its COVID-19 vacci...
# 4  “We brought that petition after CDC recommende...
# 5  “Japan sounds alarm as heart failure surges am...
# 6  president donald trump signed executive order ...
# 7  Everyone who received at least one dose of an ...
# 8  A Facebook post claims to contain the list of ...
# 9  Pfizer listed hMPV as a "side effect" of its C...
#
#                             claimant                 claimDate  \
# 0                     instagram user 2025-02-10 00:00:00+00:00
# 1                     PTI Fact Check 2025-02-13 00:02:32+00:00
# 2                     PTI Fact Check 2025-02-13 21:02:07+00:00
# 3                             Pshegs 2025-02-07 00:00:00+00:00
# 4              Robert F. Kennedy Jr. 2025-01-30 00:00:00+00:00
# 5  Social media users, Frank Bergman 2025-01-18 00:00:00+00:00
# 6                              x.com 2025-02-05 21:16:38+00:00
# 7                     Dolores Cahill 2025-01-25 00:00:00+00:00
# 8                     Isaiah Metters 2025-02-05 02:00:00+00:00
# 9                Social media posts. 2025-01-09 00:00:00+00:00
#
#                      publisher  \
# 0                    Full Fact
# 1         Press Trust of India
# 2         Press Trust of India
# 3                 FactCheckHub
# 4                FactCheck.org
# 5             Science Feedback
# 6                 Lead Stories
# 7             Science Feedback
# 8                      Rappler
# 9  Australian Associated Press
#
#                                            reviewUrl  \
# 0  https://fullfact.org/health/covid-19-exists-lo...
# 1  https://www.ptinews.com/fact-detail/pti-fact-c...
# 2  https://www.ptinews.com/fact-detail/pti-fact-c...
# 3  https://factcheckhub.com/no-pfizer-did-not-rel...
# 4  https://www.factcheck.org/2025/02/factchecking...
# 5  https://science.feedback.org/review/japanese-s...
# 6  https://leadstories.com/hoax-alert/2025/02/fac...
# 7  https://science.feedback.org/review/no-evidenc...
# 8  https://www.rappler.com/newsbreak/fact-check/p...
# 9  https://aap.com.au/factcheck/no-pfizer-did-not...
#
#                                          reviewTitle  \
# 0  Covid-19 does exist and germs can cause diseas...
# 1  PTI Fact Check: 2021 video of corpses floating...
# 2  PTI Fact Check: Podcaster Ranveer Allahbadia’s...
# 3  No, Pfizer did not release list of its COVID-1...
# 4  FactChecking RFK Jr.’s Other Health Claims Dur...
# 5  Japanese study misrepresented in posts claimin...
# 6  Fact Check: Trump Did NOT Sign Executive Order...
# 7  No evidence of mass deaths among vaccinated pe...
# 8  FACT CHECK: Post on alleged Pfizer COVID-19 va...
# 9  No, Pfizer did not list hMPV as a 'side effect...
#
#                  reviewDate                                      textualRating
# 0 2025-02-14 00:00:00+00:00  False. Covid-19 is a real disease caused by th...
# 1                       NaT                                         Misleading
# 2                       NaT                                         Misleading
# 3 2025-02-09 00:00:00+00:00  FALSE - The claim that Pfizer releases new lis...
# 4 2025-02-06 00:00:00+00:00                                              False
# 5 2025-01-18 00:00:00+00:00                                         Inaccurate
# 6 2025-02-05 21:16:38+00:00                                     Out Of Context
# 7 2025-01-25 00:00:00+00:00                                         Inaccurate
# 8 2025-02-05 02:00:00+00:00                                              False
# 9 2025-02-07 00:52:18+00:00  False. The virus was listed as an "adverse eve...

# %%
# Calculate and display the number of null values in each column
null_counts = df.isnull().sum()
print("\nNumber of null values in each column:")
print(null_counts)

# Calculate percentage of null values
null_percentages = (df.isnull().sum() / len(df)) * 100
print("\nPercentage of null values in each column:")
print(null_percentages.round(2))

# Display total number of rows
total_rows = len(df)
print(f"\nTotal number of rows: {total_rows}")
# Out:
# Number of null values in each column:
# text               0
# claimant         466
# claimDate        533
# publisher        222
# reviewUrl          0
# reviewTitle        0
# reviewDate       680
# textualRating      0
# dtype: int64
#
# Percentage of null values in each column:
# text              0.00
# claimant         13.26
# claimDate        15.16
# publisher         6.32
# reviewUrl         0.00
# reviewTitle       0.00
# reviewDate       19.35
# textualRating     0.00
# dtype: float64
#
# Total number of rows: 3515

# %% [markdown]
# # Time Analysis

# %%
# Get date ranges for claim dates and review dates
claim_date_range = {
    'earliest': pd.to_datetime(df['claimDate'].min()),
    'latest': pd.to_datetime(df['claimDate'].max())
}

review_date_range = {
    'earliest': pd.to_datetime(df['reviewDate'].min()),
    'latest': pd.to_datetime(df['reviewDate'].max())
}

print("\nClaim Date Range:")
print(f"Earliest: {claim_date_range['earliest']}")
print(f"Latest: {claim_date_range['latest']}")

print("\nReview Date Range:")
print(f"Earliest: {review_date_range['earliest']}")
print(f"Latest: {review_date_range['latest']}")
# Out:
# Claim Date Range:
# Earliest: 2016-06-20 00:00:00+00:00
# Latest: 2025-08-01 00:00:00+00:00
#
# Review Date Range:
# Earliest: 2020-01-22 00:00:00+00:00
# Latest: 2025-02-14 00:00:00+00:00

# %% [markdown]
# # Publisher Analysis

# %%
# Create a new DataFrame for publishers and their claim counts
publisher_counts = df['publisher'].value_counts().reset_index()
publisher_counts.columns = ['Publisher', 'Number of Claims']

# Count the number of reviews with None publisher
none_publisher_count = df['publisher'].isnull().sum()
print(f"Number of reviews with None publisher: {none_publisher_count}")

# Display the top 15 publishers
top_publishers = publisher_counts.head(15)
display(top_publishers)
# Out:
# Number of reviews with None publisher: 222
#            Publisher  Number of Claims
# 0          Full Fact               373
# 1         PolitiFact               300
# 2             Snopes               269
# 3    BOOM Fact Check               227
# 4     AFP Fact Check               216
# 5            AP News               182
# 6      FactCheck.org               181
# 7       Lead Stories               169
# 8          USA Today               161
# 9   Science Feedback               136
# 10        VERA Files               131
# 11         The Quint               120
# 12            FACTLY                87
# 13        Snopes.com                83
# 14          Alt News                75
