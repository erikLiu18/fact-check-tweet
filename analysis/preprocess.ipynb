# %% [markdown]
# # Preprocessing
# In this file, we remove unnecessary columns, and merge rating labels to just true and false.

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.util import load_claims_from_file, convert_claims_to_dataframe

# %%
claims = load_claims_from_file('../data/raw/fact_claims_1739933287.json')
df = convert_claims_to_dataframe(claims)

display(df.head(5))
# Out:
#                                                 text                claimant  \
# 0  Pennsylvania Gov. Josh Shapiro is “being charg...           Facebook post
# 1  Former USAID Administrator Samantha Power’s ne...            Mario Nawfal
# 2  "We found fraud and abuse, I would say those t...  President Donald Trump
# 3  “Breaking news: Taylor Swift officially banned...          Facebook posts
# 4  Early reports of four survivors show “this DC ...          Facebook posts
#
#                   claimDate publisherName   publisherSite  \
# 0 2025-02-10 00:00:00+00:00    PolitiFact  politifact.com
# 1 2025-02-09 00:00:00+00:00    PolitiFact  politifact.com
# 2 2025-02-11 00:00:00+00:00    PolitiFact  politifact.com
# 3 2025-02-04 00:00:00+00:00    PolitiFact  politifact.com
# 4 2025-01-30 00:00:00+00:00    PolitiFact  politifact.com
#
#                                            reviewUrl  \
# 0  https://www.politifact.com/factchecks/2025/feb...
# 1  https://www.politifact.com/factchecks/2025/feb...
# 2  https://www.politifact.com/article/2025/feb/13...
# 3  https://www.politifact.com/factchecks/2025/feb...
# 4  https://www.politifact.com/factchecks/2025/feb...
#
#                                          reviewTitle  \
# 0  No, Pennsylvania Gov. Josh Shapiro wasn’t char...
# 1  Former USAID head Samantha Power’s wealth didn...
# 2  Trump, Musk claim government 'fraud' without s...
# 3  You need to calm down. Taylor Swift has not be...
# 4  Initial reports that people survived Potomac p...
#
#                  reviewDate                                      textualRating
# 0 2025-02-14 00:00:00+00:00                                     Pants on Fire!
# 1 2025-02-14 00:00:00+00:00                                              False
# 2 2025-02-13 00:00:00+00:00  So far, the Trump White House has not shown ev...
# 3 2025-02-07 00:00:00+00:00                                              False
# 4 2025-02-07 00:00:00+00:00                                              False

# %% [markdown]
# ## Drop rows with no date

# %%
print(f"Number of rows in the dataframe: {len(df)}")
df_filtered = df.dropna(subset=['reviewDate'], how='all').copy()
# df_filtered = df.dropna(subset=['claimDate', 'reviewDate'], how='all').copy()
print(f"Number of rows in the filtered dataframe: {len(df_filtered)}")

display(df_filtered.head(5))
# Out:
# Number of rows in the dataframe: 52408
# Number of rows in the filtered dataframe: 41159
#                                                 text                claimant  \
# 0  Pennsylvania Gov. Josh Shapiro is “being charg...           Facebook post
# 1  Former USAID Administrator Samantha Power’s ne...            Mario Nawfal
# 2  "We found fraud and abuse, I would say those t...  President Donald Trump
# 3  “Breaking news: Taylor Swift officially banned...          Facebook posts
# 4  Early reports of four survivors show “this DC ...          Facebook posts
#
#                   claimDate publisherName   publisherSite  \
# 0 2025-02-10 00:00:00+00:00    PolitiFact  politifact.com
# 1 2025-02-09 00:00:00+00:00    PolitiFact  politifact.com
# 2 2025-02-11 00:00:00+00:00    PolitiFact  politifact.com
# 3 2025-02-04 00:00:00+00:00    PolitiFact  politifact.com
# 4 2025-01-30 00:00:00+00:00    PolitiFact  politifact.com
#
#                                            reviewUrl  \
# 0  https://www.politifact.com/factchecks/2025/feb...
# 1  https://www.politifact.com/factchecks/2025/feb...
# 2  https://www.politifact.com/article/2025/feb/13...
# 3  https://www.politifact.com/factchecks/2025/feb...
# 4  https://www.politifact.com/factchecks/2025/feb...
#
#                                          reviewTitle  \
# 0  No, Pennsylvania Gov. Josh Shapiro wasn’t char...
# 1  Former USAID head Samantha Power’s wealth didn...
# 2  Trump, Musk claim government 'fraud' without s...
# 3  You need to calm down. Taylor Swift has not be...
# 4  Initial reports that people survived Potomac p...
#
#                  reviewDate                                      textualRating
# 0 2025-02-14 00:00:00+00:00                                     Pants on Fire!
# 1 2025-02-14 00:00:00+00:00                                              False
# 2 2025-02-13 00:00:00+00:00  So far, the Trump White House has not shown ev...
# 3 2025-02-07 00:00:00+00:00                                              False
# 4 2025-02-07 00:00:00+00:00                                              False

# %% [markdown]
# ## Pick Date & Remove Columns

# %%
df_filtered['date'] = df_filtered[['claimDate', 'reviewDate']].min(axis=1)
df_filtered = df_filtered.drop(columns=['claimDate', 'reviewDate', 'publisherSite', 'reviewUrl'])

display(df_filtered.head(5))
# Out:
#                                                 text                claimant  \
# 0  Pennsylvania Gov. Josh Shapiro is “being charg...           Facebook post
# 1  Former USAID Administrator Samantha Power’s ne...            Mario Nawfal
# 2  "We found fraud and abuse, I would say those t...  President Donald Trump
# 3  “Breaking news: Taylor Swift officially banned...          Facebook posts
# 4  Early reports of four survivors show “this DC ...          Facebook posts
#
#   publisherName                                        reviewTitle  \
# 0    PolitiFact  No, Pennsylvania Gov. Josh Shapiro wasn’t char...
# 1    PolitiFact  Former USAID head Samantha Power’s wealth didn...
# 2    PolitiFact  Trump, Musk claim government 'fraud' without s...
# 3    PolitiFact  You need to calm down. Taylor Swift has not be...
# 4    PolitiFact  Initial reports that people survived Potomac p...
#
#                                        textualRating                      date
# 0                                     Pants on Fire! 2025-02-10 00:00:00+00:00
# 1                                              False 2025-02-09 00:00:00+00:00
# 2  So far, the Trump White House has not shown ev... 2025-02-11 00:00:00+00:00
# 3                                              False 2025-02-04 00:00:00+00:00
# 4                                              False 2025-01-30 00:00:00+00:00

# %% [markdown]
# ## Merge Ratings

# %%
# Group by the rating and count the number of claims for each rating
rating_counts = df_filtered['textualRating'].str.lower().value_counts().reset_index()
rating_counts.columns = ['Rating', 'Number of Claims']

print(f"Number of rows in rating_counts: {len(rating_counts)}")

# Display the top 10 rating counts
display(rating_counts.head(10))
# Out:
# Number of rows in rating_counts: 7385
#            Rating  Number of Claims
# 0           false             13980
# 1            true              3819
# 2         mixture              1639
# 3    mostly false              1477
# 4     mostly true              1155
# 5  labeled satire               980
# 6        unproven               911
# 7    miscaptioned               863
# 8      misleading               806
# 9   pants on fire               739

# %% [markdown]
# As seen above, a lot of ratings are not very concise. We leave these out.

# %%
rating_merge_dict = {
    'mixture': 'false',
    'mostly false': 'false',
    'pants on fire': 'false',
    'mostly true': 'true',
    'misleading': 'false',
    'altered': 'false',
    'four pinocchios': 'false',
    'inaccurate': 'false',
    'distorts the facts': 'false',
    'incorrect': 'false',
    'three pinocchios': 'false',
    'half true': 'false',
    'partly false': 'false',
    'correct.': 'true',
    'correct': 'true',
    'incorrect.': 'false',
    'true.': 'true',
    'false.': 'false',
    'wrong': 'false',
    'this is misleading': 'false',
    'pants on fire!': 'false',
    'mostly_accurate': 'true',
    'this is accurate': 'true',
    'this is not true.': 'false',
    'mis- leading': 'false',
    'partially_correct': 'false',
    'spins the facts': 'false',
    'spinning the facts': 'false',
    'twists the facts': 'false',
    'largely correct': 'true',
    'not true': 'false',
    'not true.': 'false',
    'one pinocchio': 'false',
    'two pinocchios': 'false',
    'this is wrong': 'false',
    'this is correct.': 'true',
    'partly true': 'false',
    'accurate': 'true',
    'not accurate': 'false',
    'not the whole story': 'false',
    'mostly accurate': 'true',
    'unproven': 'false',
    'unsupported': 'false',
    'no evidence': 'false',
    'unfounded': 'false',
    'this is misleading': 'false',
    'false: no evidence': 'false',
    'lacks evidence': 'false',
    'largely accurate': 'true',
    'misleading.': 'false',
    'there is no evidence for this.': 'false',
    'this is misleading.': 'false',
    'not proven': 'false',
    'mostly_correct': 'true',
    'that’s correct.': 'true',
}

df_filtered_merged = df_filtered.copy()
df_filtered_merged['mergedTextualRating'] = df_filtered_merged['textualRating'].str.lower().map(rating_merge_dict).fillna(df_filtered_merged['textualRating'].str.lower())

# %%
# Group by the rating and count the number of claims for each rating
rating_counts = df_filtered_merged['mergedTextualRating'].str.lower().value_counts().reset_index()
rating_counts.columns = ['Rating', 'Number of Claims']

print(f"Number of rows in rating_counts: {len(rating_counts)}")

# Display the top 10 rating counts
display(rating_counts.head(10))
# Out:
# Number of rows in rating_counts: 7331
#                 Rating  Number of Claims
# 0                false             23430
# 1                 true              5160
# 2       labeled satire               980
# 3         miscaptioned               863
# 4  correct attribution               578
# 5      missing context               474
# 6                 fake               323
# 7        misattributed               216
# 8               legend               214
# 9                 scam               203

# %%
df_filtered_merged = df_filtered_merged[df_filtered_merged['mergedTextualRating'].isin(['true', 'false'])]

print(f"Number of rows in df_filtered_merged: {len(df_filtered_merged)}")

display(df_filtered_merged.head(10))
# Out:
# Number of rows in df_filtered_merged: 28590
#                                                  text  \
# 0   Pennsylvania Gov. Josh Shapiro is “being charg...
# 1   Former USAID Administrator Samantha Power’s ne...
# 3   “Breaking news: Taylor Swift officially banned...
# 4   Early reports of four survivors show “this DC ...
# 6   Video shows President Donald Trump saying Mexi...
# 7   From the U.S. Agency for International Develop...
# 8   Photo shows Black Hawk helicopter pilot in fat...
# 9   “Pilot of Blackhawk helicopter that crashed in...
# 10  “As a Californian, we have given more to the r...
# 11  The U.S. has an egg shortage because the “Bide...
#
#                            claimant publisherName  \
# 0                     Facebook post    PolitiFact
# 1                      Mario Nawfal    PolitiFact
# 3                    Facebook posts    PolitiFact
# 4                    Facebook posts    PolitiFact
# 6                   Instagram posts    PolitiFact
# 7      U.S. Rep. Brian Mast, R-Fla.    PolitiFact
# 8                    Instagram post    PolitiFact
# 9                    Facebook posts    PolitiFact
# 10  U.S. Sen. Adam Schiff, D-Calif.    PolitiFact
# 11                 Karoline Leavitt    PolitiFact
#
#                                           reviewTitle   textualRating  \
# 0   No, Pennsylvania Gov. Josh Shapiro wasn’t char...  Pants on Fire!
# 1   Former USAID head Samantha Power’s wealth didn...           False
# 3   You need to calm down. Taylor Swift has not be...           False
# 4   Initial reports that people survived Potomac p...           False
# 6   Did Donald Trump say Mexicans call him ‘peachy...           False
# 7   Does as little as 10% of USAID go to help peop...           False
# 8   No, this photo does not show fallen Army pilot...           False
# 9   Social media posts misidentify transgender pil...  Pants on Fire!
# 10  Does California give more than it gets on disa...     Mostly True
# 11  Karoline Leavitt blames Biden for egg shortage...       Half True
#
#                         date mergedTextualRating
# 0  2025-02-10 00:00:00+00:00               false
# 1  2025-02-09 00:00:00+00:00               false
# 3  2025-02-04 00:00:00+00:00               false
# 4  2025-01-30 00:00:00+00:00               false
# 6  2025-01-30 00:00:00+00:00               false
# 7  2025-02-02 00:00:00+00:00               false
# 8  2025-02-02 00:00:00+00:00               false
# 9  2025-01-31 00:00:00+00:00               false
# 10 2025-01-26 00:00:00+00:00                true
# 11 2025-01-28 00:00:00+00:00               false

# %% [markdown]
# We keep 36685 claim reviews, of which 30968 are labeled false, and 5717 labeled true.
